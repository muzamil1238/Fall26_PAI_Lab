# %% [markdown]
# # Lab_Task_9

# %% [markdown]
# # Topic Natural Language Processing

# %% [markdown]
# # Python Code:

# %%
from textblob import TextBlob

sentences = [
    "I love this product!",
    "This is the worst experience ever.",
    "The movie was okay, not great.",
    "Amazing service and friendly staff!",
    "I am not happy with this."
]
for sentence in sentences:
    analysis = TextBlob(sentence)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    print(f"Sentence: {sentence}")
    print(f"Sentiment: {sentiment}")
    print(f"Polarity Score: {polarity}")
    print("-" * 50)
# Out:
# Sentence: I love this product!
# Sentiment: Positive
# Polarity Score: 0.625
# --------------------------------------------------
# Sentence: This is the worst experience ever.
# Sentiment: Negative
# Polarity Score: -1.0
# --------------------------------------------------
# Sentence: The movie was okay, not great.
# Sentiment: Positive
# Polarity Score: 0.04999999999999999
# --------------------------------------------------
# Sentence: Amazing service and friendly staff!
# Sentiment: Positive
# Polarity Score: 0.534375
# --------------------------------------------------
# Sentence: I am not happy with this.
# Sentiment: Negative
# Polarity Score: -0.4
# --------------------------------------------------

# %% [markdown]
# # 1.Alternative Tasks like Tokenization:

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Asus
# [nltk_data]     TUF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = "NLP is very interesting!"
tokens = text.split()

print(tokens)
# Out:
# ['NLP', 'is', 'very', 'interesting!']

# %% [markdown]
# # 2. Stopword Removal

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

text = "This is a simple NLP example"
words = text.split()

filtered = [w for w in words if w.lower() not in stopwords.words('english')]

print(filtered)
# Out:
# ['simple', 'NLP', 'example']
# [nltk_data] Downloading package stopwords to C:\Users\Asus
# [nltk_data]     TUF\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # 3. Stemming

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["running", "playing", "easily"]

for w in words:
    print(stemmer.stem(w))
# Out:
# run
# play
# easili

# %% [markdown]
# # Thank You For Viewing My Work.....
